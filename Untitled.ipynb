# %%
using Gadfly
draw(SVG("output.svg", 6inch, 3inch), plot([sin, cos], 0, 25))
p1 = plot([sin,cos],0,20)
# Out:
# Plot(...)

# %%
p1 = plot(x=[1,2,3], y=[4,5,6])
p2 = plot(x=[1,2,3], y=[6,7,8])
vstack(p1,p2)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:cx,Int64},Measures.Length{:cy,Int64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0cx,0cy),(1.0w,1.0h)),Nullable{Compose.UnitBox{S,T,U,V}}(),Nullable{Compose.Rotation{P<:NTuple{N,Measures.Measure}}}(),Nullable{Compose.Mirror}(),Compose.ListNode{Compose.Container}(Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w,0.5h),(1.0w,0.5h)),Nullable{Compose.UnitBox{S,T,U,V}}(),Nullable{Compose.Rotation{P<:NTuple{N,Measures.Measure}}}(),Nullable{Compose.Mirror}(),Compose.ListNode{Compose.Container}(Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Add{Measures.Add{Measures.Length{:w,Float64},Measures.Length{:mm,Float64}},Measures.Length{:mm,Float64}},Measures.Add{Measures.Add{Measures.Length{:h,Float64},Measures.Length{:mm,Float64}
# ...

# %%
y1 = rand(10)
y2 = rand(10)
# Out:
# 10-element Array{Float64,1}:
#  0.0849903
#  0.0739863
#  0.648627
#  0.0287163
#  0.305416
#  0.681818
#  0.950815
#  0.204769
#  0.4507
#  0.84678

# %%
y3 = Array(Float64,(10,2))
# Out:
# 10x2 Array{Float64,2}:
#  6.91383e-310  6.91383e-310
#  6.91383e-310  6.91383e-310
#  6.91383e-310  6.91383e-310
#  6.91383e-310  6.91383e-310
#  6.91383e-310  6.91383e-310
#  6.91383e-310  6.91383e-310
#  6.91383e-310  6.91383e-310
#  6.91383e-310  6.91383e-310
#  6.91383e-310  6.91383e-310
#  6.91383e-310  6.91383e-310

# %%
y3[1:10,1] = rand(10)
y3[1:10,2] = rand(10)
y3
# Out:
# 10x2 Array{Float64,2}:
#  0.723593   0.507431
#  0.0256674  0.374039
#  0.545902   0.712222
#  0.820542   0.411615
#  0.558719   0.107643
#  0.679208   0.0593593
#  0.926823   0.412197
#  0.0267056  0.123748
#  0.342363   0.0372694
#  0.36922    0.629128

# %%
plot(y=y3[:,1],x=rand(10))
# Out:
# Plot(...)

# %%
plot([layer(y=y3[:,1],x=rand(10), Geom.line) for i in 1:size(y3,2)])
# Out:
# LoadError: MethodError: `plot` has no method matching plot(::Array{Any,1})
# while loading In[32], in expression starting on line 1
#
#  in anonymous at ./no file:4294967295

# %%
layers = Array(Any,0)
layers = [layer(
    x=rand(ii), y=rand(ii),
    Geom.point)
    for ii in 1:10]
plot(layers)
# Out:
# LoadError: MethodError: `plot` has no method matching plot(::Array{Any,1})
# while loading In[49], in expression starting on line 6

# %%
plot(layers)
# Out:
# LoadError: MethodError: `plot` has no method matching plot(::Array{Any,1})
# while loading In[40], in expression starting on line 1

# %%
plot([layer(y=y3[:,i],x=rand(10), Geom.line) for i = 1])
# Out:
# LoadError: MethodError: `plot` has no method matching plot(::Array{Any,1})
# while loading In[38], in expression starting on line 1
#
#  in anonymous at ./no file:4294967295

# %%
using DataFrames
x = 1:10
df1 = DataFrame(x=x, y=2x, label="double")
df2 = DataFrame(x=x, y=x.^2, label="square")
df3 = DataFrame(x=x, y=1./x, label="inverse")

df = vcat(df1, df2, df3)
df = vcat(df,DataFrame(x=x,y=x.^0.5,label="test"))
#push!(df,DataFrame(x=x,y=x.^0.5,label="test"))

p = plot(df, x="x", y="y", color="label", Geom.line)
# Out:
# Plot(...)
